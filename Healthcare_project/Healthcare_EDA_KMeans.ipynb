# %% [markdown]
# # Healthcare data EDA

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, silhouette_score
from sklearn.cluster import KMeans

pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Healthcare dataset attributes
#
# - **Name**: Column represents patient's name on health record <br>
# - **Age**: age of patient at time of admission in years <br>
# - **Gender**: patient gender either "Male" or "Female" <br>
# - **Blood type**: Patient's bloodtype of the common ones "A+", "O-" etc <br>
# - **Medical condition**: primary medical condition or diagnosis associated with patient <br>
# - **Date of admission**: date patient was admitted to the facility <br>
# - **Doctor**: Name of doctor responsible for care during admission <br>
# - **Hospital**: Name of hospital or facility where patient was admitted <br>
# - **Insurance provider**: patient's insurance provider <br>
# - **Billing amount**: amount of money billed to patient for their healthcare services during admission <br>
# - **Room number**: Room number where patient was accomodated during admission <br>
# - **Discharge date**: Date patient was discharged from healthcare facility <br>
# - **Medication**: Identifies medication prescribed during their admission <br>
# - **Test results**: Describes the results of medical tests conducted during patient's admission

# %%
# Load healthcare data
data = pd.read_csv('healthcare_dataset.csv')

data.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ## Data cleaning

# %%
data.shape
# Out:
# (55500, 15)

# %%
# Check for missing data 
data.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.4+ MB

# %%
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %% [markdown]
# Note: The minimum billing amount is negative - could suggest multiple entries per person?

# %%
# Count number of negative billing amount entries
(data['Billing Amount']<0).sum()
# Out:
# 108

# %%
# Find the people with multiple entries/ duplicates with the same name 

# Convert Name strings to all lowercase
data['Name'] = data['Name'].str.lower()

# Number of unique names
print (f'Number of unique names : {data['Name'].nunique()}')

# Count the number of entries per name
duplicate_values = data['Name'].value_counts()

# Names that occur twice or more
items_occurring_more = duplicate_values[duplicate_values >= 2].index
print(f'Name with more two or more entries: {items_occurring_more}')

print (f'Number of unique names in duplicate names list : {items_occurring_more.nunique()}')
# Out:
# Number of unique names : 40235
# Name with more two or more entries: Index(['michael williams', 'michael smith', 'robert smith', 'james brown',
#        'james smith', 'james williams', 'john smith', 'john johnson',
#        'kimberly smith', 'david johnson',
#        ...
#        'marisa golden', 'todd garrett', 'justin griffin', 'julie rojas',
#        'amy owen', 'kathleen coleman', 'nancy hamilton', 'laura ryan',
#        'danielle ingram', 'katie johnson'],
#       dtype='object', name='Name', length=9740)
# Number of unique names in duplicate names list : 9740

# %%
# Get rows with Name occuring twice or more in the dataset
filtered_rows = data[data['Name'].isin(items_occurring_more)]
print (f'Total number of duplicates in dataset: {len(filtered_rows)}')
# Out:
# Total number of duplicates in dataset: 25005

# %% [markdown]
# There are duplicate people with the same name, different ages but some have the same dates of admission and room numbers, medication etc. i.e. with many signs that there are duplicate entries except with differences in e.g. Age. <br>
# Lets have a deeper look at some examples below.

# %%
data.loc[data['Name'] == 'michael williams']
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 2021   michael williams   38    Male        AB-            Cancer
# 2983   michael williams   50  Female         O+            Cancer
# 6086   michael williams   55    Male         A-      Hypertension
# 7339   michael williams   49    Male        AB-          Diabetes
# 7431   michael williams   85  Female         O+            Cancer
# 7688   michael williams   40  Female         A+          Diabetes
# 11431  michael williams   47    Male        AB-          Diabetes
# 14894  michael williams   23  Female         A+           Obesity
# 15187  michael williams   70    Male         B+            Asthma
# 20430  michael williams   38  Female         B-          Diabetes
# 24294  michael williams   83  Female        AB-            Cancer
# 24679  michael williams   41    Male         B-      Hypertension
# 29772  michael williams   76    Male         O+          Diabetes
# 30810  michael williams   66    Male         A+           Obesity
# 31286  michael williams   72    Male        AB+            Cancer
# 35659  michael williams   37  Female         O-            Asthma
# 36440  michael williams   34  Female         O-            Asthma
# 40145  michael williams   78  Female         A+      Hypertension
# 40979  michael williams   21    Male         O-            Cancer
# 41222  michael williams   29  Female         O-         Arthritis
# 44576  michael williams   46  Female         A-      Hypertension
# 48097  michael williams   19  Female         B-      Hypertension
# 50335  michael williams   17  Female         B-      Hypertension
# 54668  michael williams   45    Male         B-      Hypertension
#
#       Date of Admission             Doctor                        Hospital  \
# 2021         2021-08-07     Kenneth Vargas  Richmond, and Williams Cabrera
# 2983         2020-05-11      Jason Sanchez                  Randall-Juarez
# 6086         2019-12-05       Jamie Hodges                      LLC Taylor
# 7339         2023-03-29         Sarah King       Medina, and Forbes Arnold
# 7431         2022-07-14     Rachel Ramirez                    Thompson Ltd
# 7688         2023-11-19       Julie Little                      Wood-Noble
# 11431        2020-12-25    Jared Rasmussen        and Harris Brewer, Young
# 14894        2021-09-14          Scott Cox         Reyes and Walker Woods,
# 15187        2022-06-30      John Gonzalez         Weaver Davis Bates, and
# 20430        2021-10-12         Jake Patel                  Abbott-Coleman
# 24294        2022-04-28  Catherine Mcguire      Taylor Jones, and Ferguson
# 24679        2023-09-24    Pamela Franklin                     May-Wallace
# 29772        2020-07-03        Brian Giles                      Miller Inc
# 30810        2023-10-24         Mary Banks                    Russell-Bond
# 31286        2022-12-02        Dylan White                Cooper-Wilkerson
# 35659        2021-02-14       Diane Torres     Edwards and Thompson Reyes,
# 36440        2022-05-08       Brittney Lee                  Brooks-Simpson
# 40145        2021-12-25        John Norton                    Jordan-Davis
# 40979        2021-08-05      Evan Williams                   Robertson PLC
# 41222        2024-03-08     Shannon Dawson                   Haas and Sons
# 44576        2020-02-23     Felicia Bowers                        PLC Wong
# 48097        2023-01-10          Kyle Ward                      Brown-Bell
# 50335        2023-01-10          Kyle Ward                      Brown-Bell
# 54668        2023-09-24    Pamela Franklin                     May-Wallace
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 2021    UnitedHealthcare    47511.507353          327         Urgent
# 2983               Cigna     2953.357870          234      Emergency
# 6086               Cigna     8407.060526          359       Elective
# 7339               Cigna     4678.553455          174         Urgent
# 7431            Medicare    19373.416683          487      Emergency
# 7688    UnitedHealthcare     7659.045824          284         Urgent
# 11431   UnitedHealthcare    20170.808021          455         Urgent
# 14894              Aetna    37243.522084          224         Urgent
# 15187              Aetna     4697.732433          116      Emergency
# 20430              Cigna    19751.999497          392      Emergency
# 24294         Blue Cross    20425.700808          248       Elective
# 24679         Blue Cross     7063.088798          289         Urgent
# 29772              Aetna    43107.023150          471      Emergency
# 30810              Cigna    47142.322277          332         Urgent
# 31286              Aetna     3755.190088          451       Elective
# 35659              Aetna    45861.702851          103       Elective
# 36440              Aetna    18398.028033          354      Emergency
# 40145         Blue Cross    45908.445937          301       Elective
# 40979              Cigna    15726.728811          292       Elective
# 41222              Cigna    50566.362122          358         Urgent
# 44576           Medicare     3696.082197          455      Emergency
# 48097           Medicare    37039.965352          320      Emergency
# 50335           Medicare    37039.965352          320      Emergency
# 54668         Blue Cross     7063.088798          289         Urgent
#
#       Discharge Date   Medication  Test Results
# 2021      2021-08-14      Lipitor        Normal
# 2983      2020-06-07    Ibuprofen        Normal
# 6086      2019-12-15      Lipitor        Normal
# 7339      2023-04-06    Ibuprofen      Abnormal
# 7431      2022-08-03      Lipitor      Abnormal
# 7688      2023-11-29   Penicillin        Normal
# 11431     2020-12-27      Aspirin  Inconclusive
# 14894     2021-10-09      Aspirin      Abnormal
# 15187     2022-07-07   Penicillin  Inconclusive
# 20430     2021-10-17  Paracetamol  Inconclusive
# 24294     2022-05-05      Aspirin        Normal
# 24679     2023-10-17      Lipitor      Abnormal
# 29772     2020-07-26  Paracetamol        Normal
# 30810     2023-11-03  Paracetamol        Normal
# 31286     2022-12-26      Aspirin        Normal
# 35659     2021-02-17      Aspirin  Inconclusive
# 36440     2022-05-28      Lipitor  Inconclusive
# 40145     2022-01-03      Lipitor        Normal
# 40979     2021-08-07   Penicillin        Normal
# 41222     2024-03-20   Penicillin        Normal
# 44576     2020-02-26      Aspirin  Inconclusive
# 48097     2023-01-29   Penicillin  Inconclusive
# 50335     2023-01-29   Penicillin  Inconclusive
# 54668     2023-10-17      Lipitor      Abnormal

# %%
data.loc[data['Name'] == 'david munoz']
# Out:
#               Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 2491   david munoz   31   Male        AB+          Diabetes        2022-12-20
# 46648  david munoz   19   Male         A-            Cancer        2022-08-04
# 53672  david munoz   28   Male        AB+          Diabetes        2022-12-20
#
#                Doctor      Hospital Insurance Provider  Billing Amount  \
# 2491    Maurice Davis   Wall-Weaver           Medicare    25773.328236
# 46648  Jamie Gonzales  Olsen-Thomas         Blue Cross    32454.950609
# 53672   Maurice Davis   Wall-Weaver           Medicare    25773.328236
#
#        Room Number Admission Type Discharge Date  Medication  Test Results
# 2491           406       Elective     2023-01-09  Penicillin  Inconclusive
# 46648          406         Urgent     2022-08-17     Aspirin  Inconclusive
# 53672          406       Elective     2023-01-09  Penicillin  Inconclusive

# %%
# Explore a few more ...
for name in filtered_rows['Name'][0:5]:
    print (filtered_rows.loc[data['Name'] == name])
# Out:
#                 Name  Age  Gender Blood Type Medical Condition  \
# 4      adrienne bell   43  Female        AB+            Cancer
# 50144  adrienne bell   44  Female        AB+            Cancer
#
#       Date of Admission          Doctor     Hospital Insurance Provider  \
# 4            2022-09-19  Kathleen Hanna  White-White              Aetna
# 50144        2022-09-19  Kathleen Hanna  White-White              Aetna
#
#        Billing Amount  Room Number Admission Type Discharge Date  Medication  \
# 4        14238.317814          458         Urgent     2022-10-09  Penicillin
# 50144    14238.317814          458         Urgent     2022-10-09  Penicillin
#
#       Test Results
# 4         Abnormal
# 50144     Abnormal
#                 Name  Age  Gender Blood Type Medical Condition  \
# 5      emily johnson   36    Male         A+            Asthma
# 29074  emily johnson   29  Female         A-         Arthritis
# 35317  emily johnson   19  Female         A+            Cancer
# 37505  emily johnson   53  Female         O-      Hypertension
#
#       Date of Admission           Doctor                    Hospital  \
# 5            2023-12-20    Taylor Newton              Nunez-Humphrey
# 29074        2020-11-25   Jennifer Lyons                    Ltd Ruiz
# 35317        2020-08-20  Tommy Miles Jr.              Roberts-Taylor
# 37505        2019-10-24       Gary Mills  Kim, and Figueroa Robinson
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 5       UnitedHealthcare    48145.110951          389         Urgent
# 29074         Blue Cross    33148.204825          397       Elective
# 35317         Blue Cross    14437.608902          392      Emergency
# 37505              Aetna    31978.996789          259      Emergency
#
#       Discharge Date   Medication Test Results
# 5         2023-12-24    Ibuprofen       Normal
# 29074     2020-12-19      Aspirin       Normal
# 35317     2020-09-03  Paracetamol       Normal
# 37505     2019-11-08  Paracetamol     Abnormal
#                  Name  Age  Gender Blood Type Medical Condition  \
# 6      edward edwards   21  Female        AB-          Diabetes
# 22667  edward edwards   43  Female         B+           Obesity
# 39134  edward edwards   82  Female         A+            Cancer
#
#       Date of Admission         Doctor                    Hospital  \
# 6            2020-11-03    Kelly Olson             Group Middleton
# 22667        2022-11-08  Lisa Gonzalez  and Mitchell Kelly, Walker
# 39134        2019-09-10  Brittany Cruz                 Group Ellis
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 6               Medicare    19580.872345          389      Emergency
# 22667           Medicare    30217.701907          294      Emergency
# 39134              Aetna    16788.308699          340         Urgent
#
#       Discharge Date   Medication  Test Results
# 6         2020-11-15  Paracetamol  Inconclusive
# 22667     2022-11-12  Paracetamol      Abnormal
# 39134     2019-09-30      Lipitor  Inconclusive
#                      Name  Age  Gender Blood Type Medical Condition  \
# 7      christina martinez   20  Female         A+            Cancer
# 27975  christina martinez   74    Male        AB+          Diabetes
# 32052  christina martinez   41    Male         O+         Arthritis
#
#       Date of Admission             Doctor                     Hospital  \
# 7            2021-12-28     Suzanne Thomas  Powell Robinson and Valdez,
# 27975        2022-01-08  Patricia Williams     Stephens and Clark, Mann
# 32052        2021-09-26     Matthew Glover              Sons and Miller
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 7                  Cigna    45820.462722          277      Emergency
# 27975              Aetna     6631.126917          246      Emergency
# 32052   UnitedHealthcare    18892.309155          280      Emergency
#
#       Discharge Date   Medication  Test Results
# 7         2022-01-07  Paracetamol  Inconclusive
# 27975     2022-01-19   Penicillin      Abnormal
# 32052     2021-10-07    Ibuprofen  Inconclusive
#                    Name  Age  Gender Blood Type Medical Condition  \
# 9      christopher berg   58  Female        AB-            Cancer
# 16851  christopher berg   72    Male         A+            Cancer
# 28354  christopher berg   43    Male        AB-          Diabetes
#
#       Date of Admission            Doctor                 Hospital  \
# 9            2021-05-23       Heather Day           Padilla-Walker
# 16851        2019-11-08  Veronica Wallace  Gill Wilson Conley, and
# 28354        2021-06-28    Hannah Trevino          Wilson Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 9       UnitedHealthcare    19784.631062          249       Elective
# 16851           Medicare    30887.886490          322      Emergency
# 28354         Blue Cross    42811.264946          328      Emergency
#
#       Discharge Date   Medication  Test Results
# 9         2021-06-22  Paracetamol  Inconclusive
# 16851     2019-11-17   Penicillin  Inconclusive
# 28354     2021-07-11   Penicillin      Abnormal

# %%
# Are duplicate entires of people associated with being reinbursed i.e. a change in billing amount? 
refund = data.loc[data['Billing Amount'] < 0]
filtered_refund = refund.isin(filtered_rows)
filtered_refund['Name'].value_counts()
# Out:
# Name
# False    60
# True     48
# Name: count, dtype: int64

# %% [markdown]
# From exploration above, lets define what we are going to class as a 'duplicate' in this dataset and then we will handle them. <br>
# A **duplicate** is one where the **Name**, **Date of Admission**, **Discharge Date**, **Gender** and **Blood Types**  are the same as another entry. <br>
# I have ensured Billing Amount is not included in the above list as billing charges to a given person may change.

# %%
# Handling duplicates

# Using the subset 'filtered_rows', get duplicates based on criteria
duplicate_mask = filtered_rows.duplicated(
    subset=['Name', 'Blood Type', 'Date of Admission', 'Discharge Date'], 
    keep='first'
)

duplicate_indices = filtered_rows[duplicate_mask].index
print(f"Number of true duplicates to remove: {len(duplicate_indices)}")
# Out:
# Number of true duplicates to remove: 5500

# %%
# Drop duplicates based on indices from original dataset
data_clean = data.drop(index=duplicate_indices)
print(f"Final cleaned dataset shape: {data_clean.shape}")
# Out:
# Final cleaned dataset shape: (50000, 15)

# %%
# Save cleaned data to csv
data_clean.to_csv('healthcare_dataset_clean.csv', index=False)

# %%
# Read in cleaned data
df = pd.read_csv('healthcare_dataset_clean.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Hospital admissions per month
admissions_per_month = pd.to_datetime(df['Date of Admission']).dt.month.value_counts().sort_index()
average_admissions= sum(admissions_per_month)/len(admissions_per_month)

# sns.barplot(admissions_per_month, x='Month', y='Number of patients admitted')
sns.barplot(admissions_per_month, color='skyblue')
plt.axhline(y=average_admissions, color='r', linestyle='--')
plt.xlabel('Month')
plt.ylabel('Number of Admissions')

print(f'The average number of admissions for a given month is {average_admissions}')
# Out:
# The average number of admissions for a given month is 4166.666666666667

# %%
# Length of stay
d1 = pd.to_datetime(df['Date of Admission'])
d2 = pd.to_datetime(df['Discharge Date'])

length_of_stay = (d2-d1)

print(f'Average length of stay: {length_of_stay.mean().days} days')
print(f'Maximum length of stay: {length_of_stay.max().days} days')
print(f'Minimum length of stay: {length_of_stay.min().days} day')
# Out:
# Average length of stay: 15 days
# Maximum length of stay: 30 days
# Minimum length of stay: 1 day

# %%
# Relationship between age and medical condition and gender
ax=sns.boxplot(data=df, x='Medical Condition', y='Age', hue='Gender', gap=0.15, palette='colorblind')
sns.move_legend(ax,"upper center", bbox_to_anchor=(0.5, 1.15), frameon=False, ncol=2)

# %%
# Relationship between gender and test results
result = df['Test Results']
# sns.barplot(data=data, x=result, y='Gender', gap=0.15, palette='colorblind')
# sns.move_legend(ax,"upper center", bbox_to_anchor=(0.5, 1.15), frameon=False, ncol=2)
result
# Out:
# 0              Normal
# 1        Inconclusive
# 2              Normal
# 3            Abnormal
# 4            Abnormal
# 5              Normal
# 6        Inconclusive
# 7        Inconclusive
# 8            Abnormal
# 9        Inconclusive
# 10             Normal
# 11       Inconclusive
# 12           Abnormal
# 13             Normal
# 14             Normal
# 15       Inconclusive
# 16             Normal
# 17           Abnormal
# 18           Abnormal
# 19             Normal
# 20             Normal
# 21             Normal
# 22       Inconclusive
# 23       Inconclusive
# 24       Inconclusive
# 25           Abnormal
# 26             Normal
# 27           Abnormal
# 28             Normal
# 29           Abnormal
# 30       Inconclusive
# 31           Abnormal
# 32             Normal
# 33             Normal
# 34             Normal
# 35           Abnormal
# 36       Inconclusive
# 37             Normal
# 38           Abnormal
# 39           Abnormal
# 40             Normal
# 41             Normal
# 42             Normal
# 43             Normal
# 44           Abnormal
# 45             Normal
# 46             Normal
# 47             Normal
# 48           Abnormal
# 49           Abnormal
# 50       Inconclusive
# 51           Abnormal
# 52       Inconclusive
# 53           Abnormal
# 54       Inconclusive
# 55       Inconclusive
# 56             Normal
# 57       Inconclusive
# 58             Normal
# 59           Abnormal
# 60       Inconclusive
# 61       Inconclusive
# 62             Normal
# 63       Inconclusive
# 64           Abnormal
# 65           Abnormal
# 66           Abnormal
# 67       Inconclusive
# 68             Normal
# 69             Normal
# 70             Normal
# 71       Inconclusive
# 72           Abnormal
# 73           Abnormal
# 74           Abnormal
# 75       Inconclusive
# 76             Normal
# 77       Inconclusive
# 78       Inconclusive
# 79       Inconclusive
# 80           Abnormal
# 81           Abnormal
# 82           Abnormal
# 83       Inconclusive
# 84           Abnormal
# 85             Normal
# 86       Inconclusive
# 87       Inconclusive
# 88           Abnormal
# 89       Inconclusive
# 90           Abnormal
# 91           Abnormal
# 92       Inconclusive
# 93       Inconclusive
# 94       Inconclusive
# 95           Abnormal
# 96           Abnormal
# 97             Normal
# 98             Normal
# 99           Abnormal
# 100            Normal
# 101            Normal
# 102            Normal
# 103      Inconclusive
# 104          Abnormal
# 105          Abnormal
# 106      Inconclusive
# 107          Abnormal
# 108          Abnormal
# 109          Abnormal
# 110            Normal
# 111            Normal
# 112            Normal
# 113      Inconclusive
# 114            Normal
# 115          Abnormal
# 116      Inconclusive
# 117      Inconclusive
# 118          Abnormal
# 119          Abnormal
# 120            Normal
# 121          Abnormal
# 122            Normal
# 123      Inconclusive
# 124      Inconclusive
# 125            Normal
# 126      Inconclusive
# 127          Abnormal
# 128          Abnormal
# 129      Inconclusive
# 130            Normal
# 131            Normal
# 132            Normal
# 133            Normal
# 134            Normal
# 135          Abnormal
# 136          Abnormal
# 137      Inconclusive
# 138          Abnormal
# 139            Normal
# 140      Inconclusive
# 141            Normal
# 142      Inconclusive
# 143            Normal
# 144      Inconclusive
# 145          Abnormal
# 146          Abnormal
# 147      Inconclusive
# 148      Inconclusive
# 149      Inconclusive
# 150      Inconclusive
# 151            Normal
# 152          Abnormal
# 153          Abnormal
# 154          Abnormal
# 155            Normal
# 156          Abnormal
# 157          Abnormal
# 158          Abnormal
# 159            Normal
# 160          Abnormal
# 161            Normal
# 162          Abnormal
# 163      Inconclusive
# 164          Abnormal
# 165          Abnormal
# 166          Abnormal
# 167      Inconclusive
# 168          Abnormal
# 169            Normal
# 170          Abnormal
# 171            Normal
# 172            Normal
# 173            Normal
# 174            Normal
# 175      Inconclusive
# 176            Normal
# 177          Abnormal
# 178          Abnormal
# 179            Normal
# 180      Inconclusive
# 181      Inconclusive
# 182            Normal
# 183      Inconclusive
# 184      Inconclusive
# 185          Abnormal
# 186            Normal
# 187      Inconclusive
# 188          Abnormal
# 189      Inconclusive
# 190      Inconclusive
# 191      Inconclusive
# 192            Normal
# 193          Abnormal
# 194            Normal
# 195      Inconclusive
# 196      Inconclusive
# 197          Abnormal
# 198          Abnormal
# 199          Abnormal
# 200          Abnormal
# 201          Abnormal
# 202          Abnormal
# 203      Inconclusive
# 204          Abnormal
# 205            Normal
# 206      Inconclusive
# 207          Abnormal
# 208            Normal
# 209      Inconclusive
# 210      Inconclusive
# 211      Inconclusive
# 212          Abnormal
# 213      Inconclusive
# 214            Normal
# 215          Abnormal
# 216      Inconclusive
# 217            Normal
# 218          Abnormal
# 219            Normal
# 220          Abnormal
# 221          Abnormal
# 222            Normal
# 223            Normal
# 224      Inconclusive
# 225          Abnormal
# 226      Inconclusive
# 227            Normal
# 228      Inconclusive
# 229          Abnormal
# 230            Normal
# 231      Inconclusive
# 232            Normal
# 233      Inconclusive
# 234          Abnormal
# 235      Inconclusive
# 236          Abnormal
# 237            Normal
# 238            Normal
# 239      Inconclusive
# 240            Normal
# 241      Inconclusive
# 242            Normal
# 243            Normal
# 244            Normal
# 245            Normal
# 246            Normal
# 247      Inconclusive
# 248            Normal
# 249          Abnormal
# 250      Inconclusive
# 251          Abnormal
# 252            Normal
# 253          Abnormal
# 254            Normal
# 255          Abnormal
# 256            Normal
# 257          Abnormal
# 258      Inconclusive
# 259          Abnormal
# 260            Normal
# 261      Inconclusive
# 262            Normal
# 263      Inconclusive
# 264          Abnormal
# 265          Abnormal
# 266            Normal
# 267            Normal
# 268      Inconclusive
# 269            Normal
# 270            Normal
# 271      Inconclusive
# 272      Inconclusive
# 273          Abnormal
# 274            Normal
# 275          Abnormal
# 276            Normal
# 277            Normal
# 278      Inconclusive
# 279            Normal
# 280          Abnormal
# 281      Inconclusive
# 282      Inconclusive
# 283      Inconclusive
# 284          Abnormal
# 285          Abnormal
# 286          Abnormal
# 287          Abnormal
# 288      Inconclusive
# 289            Normal
# 290      Inconclusive
# 291            Normal
# 292            Normal
# 293          Abnormal
# 294          Abnormal
# 295      Inconclusive
# 296          Abnormal
# 297            Normal
# 298            Normal
# 299          Abnormal
# 300          Abnormal
# 301          Abnormal
# 302          Abnormal
# 303            Normal
# 304      Inconclusive
# 305            Normal
# 306          Abnormal
# 307            Normal
# 308      Inconclusive
# 309            Normal
# 310            Normal
# 311          Abnormal
# 312            Normal
# 313          Abnormal
# 314          Abnormal
# 315          Abnormal
# 316      Inconclusive
# 317          Abnormal
# 318      Inconclusive
# 319      Inconclusive
# 320            Normal
# 321            Normal
# 322          Abnormal
# 323          Abnormal
# 324      Inconclusive
# 325          Abnormal
# 326            Normal
# 327          Abnormal
# 328            Normal
# 329            Normal
# 330          Abnormal
# 331          Abnormal
# 332          Abnormal
# 333            Normal
# 334          Abnormal
# 335          Abnormal
# 336            Normal
# 337          Abnormal
# 338            Normal
# 339      Inconclusive
# 340            Normal
# 341            Normal
# 342          Abnormal
# 343            Normal
# 344      Inconclusive
# 345      Inconclusive
# 346            Normal
# 347          Abnormal
# 348      Inconclusive
# 349      Inconclusive
# 350      Inconclusive
# 351          Abnormal
# 352          Abnormal
# 353            Normal
# 354            Normal
# 355            Normal
# 356            Normal
# 357            Normal
# 358          Abnormal
# 359      Inconclusive
# 360          Abnormal
# 361          Abnormal
# 362      Inconclusive
# 363      Inconclusive
# 364          Abnormal
# 365      Inconclusive
# 366      Inconclusive
# 367            Normal
# 368            Normal
# 369          Abnormal
# 370          Abnormal
# 371          Abnormal
# 372      Inconclusive
# 373          Abnormal
# 374            Normal
# 375      Inconclusive
# 376      Inconclusive
# 377      Inconclusive
# 378          Abnormal
# 379      Inconclusive
# 380      Inconclusive
# 381          Abnormal
# 382      Inconclusive
# 383      Inconclusive
# 384          Abnormal
# 385      Inconclusive
# 386            Normal
# 387          Abnormal
# 388            Normal
# 389      Inconclusive
# 390            Normal
# 391            Normal
# 392            Normal
# 393            Normal
# 394            Normal
# 395      Inconclusive
# 396            Normal
# 397            Normal
# 398      Inconclusive
# 399            Normal
# 400          Abnormal
# 401          Abnormal
# 402          Abnormal
# 403      Inconclusive
# 404            Normal
# 405          Abnormal
# 406          Abnormal
# 407            Normal
# 408      Inconclusive
# 409            Normal
# 410          Abnormal
# 411          Abnormal
# 412          Abnormal
# 413      Inconclusive
# 414            Normal
# 415            Normal
# 416            Normal
# 417      Inconclusive
# 418            Normal
# 419            Normal
# 420            Normal
# 421            Normal
# 422          Abnormal
# 423      Inconclusive
# 424      Inconclusive
# 425          Abnormal
# 426          Abnormal
# 427            Normal
# 428          Abnormal
# 429      Inconclusive
# 430      Inconclusive
# 431          Abnormal
# 432          Abnormal
# 433          Abnormal
# 434          Abnormal
# 435            Normal
# 436          Abnormal
# 437            Normal
# 438          Abnormal
# 439          Abnormal
# 440      Inconclusive
# 441      Inconclusive
# 442      Inconclusive
# 443            Normal
# 444          Abnormal
# 445            Normal
# 446            Normal
# 447      Inconclusive
# 448          Abnormal
# 449      Inconclusive
# 450      Inconclusive
# 451          Abnormal
# 452          Abnormal
# 453            Normal
# 454            Normal
# 455      Inconclusive
# 456          Abnormal
# 457      Inconclusive
# 458            Normal
# 459      Inconclusive
# 460            Normal
# 461          Abnormal
# 462      Inconclusive
# 463            Normal
# 464      Inconclusive
# 465            Normal
# 466      Inconclusive
# 467          Abnormal
# 468            Normal
# 469      Inconclusive
# 470          Abnormal
# 471      Inconclusive
# 472            Normal
# 473            Normal
# 474      Inconclusive
# 475            Normal
# 476      Inconclusive
# 477            Normal
# 478          Abnormal
# 479          Abnormal
# 480      Inconclusive
# 481            Normal
# 482            Normal
# 483          Abnormal
# 484            Normal
# 485          Abnormal
# 486      Inconclusive
# 487      Inconclusive
# 488      Inconclusive
# 489      Inconclusive
# 490      Inconclusive
# 491      Inconclusive
# 492          Abnormal
# 493            Normal
# 494            Normal
# 495      Inconclusive
# 496      Inconclusive
# 497      Inconclusive
# 498      Inconclusive
# 499            Normal
# 500          Abnormal
# 501          Abnormal
# 502      Inconclusive
# 503            Normal
# 504            Normal
# 505            Normal
# 506      Inconclusive
# 507      Inconclusive
# 508          Abnormal
# 509          Abnormal
# 510          Abnormal
# 511            Normal
# 512      Inconclusive
# 513      Inconclusive
# 514          Abnormal
# 515          Abnormal
# 516          Abnormal
# 517      Inconclusive
# 518      Inconclusive
# 519          Abnormal
# 520      Inconclusive
# 521          Abnormal
# 522      Inconclusive
# 523          Abnormal
# 524      Inconclusive
# 525          Abnormal
# 526      Inconclusive
# 527          Abnormal
# 528      Inconclusive
# 529          Abnormal
# 530          Abnormal
# 531      Inconclusive
# 532          Abnormal
# 533            Normal
# 534      Inconclusive
# 535      Inconclusive
# 536            Normal
# 537      Inconclusive
# 538      Inconclusive
# 539      Inconclusive
# 540            Normal
# 541          Abnormal
# 542          Abnormal
# 543          Abnormal
# 544          Abnormal
# 545            Normal
# 546      Inconclusive
# 547      Inconclusive
# 548      Inconclusive
# 549          Abnormal
# 550            Normal
# 551            Normal
# 552          Abnormal
# 553      Inconclusive
# 554            Normal
# 555      Inconclusive
# 556          Abnormal
# 557          Abnormal
# 558      Inconclusive
# 559            Normal
# 560            Normal
# 561          Abnormal
# 562          Abnormal
# 563            Normal
# 564      Inconclusive
# 565          Abnormal
# 566          Abnormal
# 567          Abnormal
# 568            Normal
# 569      Inconclusive
# 570            Normal
# 571            Normal
# 572            Normal
# 573      Inconclusive
# 574      Inconclusive
# 575          Abnormal
# 576          Abnormal
# 577            Normal
# 578            Normal
# 579      Inconclusive
# 580          Abnormal
# 581            Normal
# 582          Abnormal
# 583            Normal
# 584      Inconclusive
# 585          Abnormal
# 586            Normal
# 587          Abnormal
# 588            Normal
# 589      Inconclusive
# 590            Normal
# 591            Normal
# 592      Inconclusive
# 593            Normal
# 594      Inconclusive
# 595          Abnormal
# 596            Normal
# 597      Inconclusive
# 598          Abnormal
# 599      Inconclusive
# 600            Normal
# 601      Inconclusive
# 602          Abnormal
# 603            Normal
# 604          Abnormal
# 605      Inconclusive
# 606      Inconclusive
# 607          Abnormal
# 608            Normal
# 609          Abnormal
# 610      Inconclusive
# 611            Normal
# 612      Inconclusive
# 613          Abnormal
# 614            Normal
# 615            Normal
# 616            Normal
# 617      Inconclusive
# 618            Normal
# 619      Inconclusive
# 620          Abnormal
# 621            Normal
# 622      Inconclusive
# 623            Normal
# 624          Abnormal
# 625            Normal
# 626            Normal
# 627      Inconclusive
# 628            Normal
# 629      Inconclusive
# 630            Normal
# 631      Inconclusive
# 632            Normal
# 633      Inconclusive
# 634          Abnormal
# 635          Abnormal
# 636      Inconclusive
# 637          Abnormal
# 638            Normal
# 639          Abnormal
# 640      Inconclusive
# 641      Inconclusive
# 642            Normal
# 643          Abnormal
# 644            Normal
# 645            Normal
# 646          Abnormal
# 647      Inconclusive
# 648            Normal
# 649            Normal
# 650          Abnormal
# 651          Abnormal
# 652            Normal
# 653            Normal
# 654          Abnormal
# 655          Abnormal
# 656            Normal
# 657      Inconclusive
# 658      Inconclusive
# 659      Inconclusive
# 660          Abnormal
# 661      Inconclusive
# 662      Inconclusive
# 663      Inconclusive
# 664          Abnormal
# 665          Abnormal
# 666            Normal
# 667          Abnormal
# 668            Normal
# 669          Abnormal
# 670            Normal
# 671          Abnormal
# 672      Inconclusive
# 673          Abnormal
# 674      Inconclusive
# 675          Abnormal
# 676      Inconclusive
# 677            Normal
# 678      Inconclusive
# 679      Inconclusive
# 680      Inconclusive
# 681      Inconclusive
# 682          Abnormal
# 683            Normal
# 684      Inconclusive
# 685          Abnormal
# 686      Inconclusive
# 687      Inconclusive
# 688      Inconclusive
# 689          Abnormal
# 690          Abnormal
# 691          Abnormal
# 692          Abnormal
# 693      Inconclusive
# 694      Inconclusive
# 695      Inconclusive
# 696          Abnormal
# 697          Abnormal
# 698      Inconclusive
# 699          Abnormal
# 700      Inconclusive
# 701          Abnormal
# 702          Abnormal
# 703            Normal
# 704      Inconclusive
# 705            Normal
# 706          Abnormal
# 707      Inconclusive
# 708          Abnormal
# 709          Abnormal
# 710          Abnormal
# 711          Abnormal
# 712      Inconclusive
# 713          Abnormal
# 714            Normal
# 715          Abnormal
# 716          Abnormal
# 717      Inconclusive
# 718            Normal
# 719          Abnormal
# 720      Inconclusive
# 721            Normal
# 722      Inconclusive
# 723      Inconclusive
# 724            Normal
# 725      Inconclusive
# 726          Abnormal
# 727            Normal
# 728            Normal
# 729            Normal
# 730          Abnormal
# 731            Normal
# 732      Inconclusive
# 733          Abnormal
# 734          Abnormal
# 735            Normal
# 736      Inconclusive
# 737          Abnormal
# 738            Normal
# 739            Normal
# 740          Abnormal
# 741      Inconclusive
# 742          Abnormal
# 743          Abnormal
# 744            Normal
# 745      Inconclusive
# 746            Normal
# 747            Normal
# 748          Abnormal
# 749            Normal
# 750          Abnormal
# 751            Normal
# 752      Inconclusive
# 753          Abnormal
# 754          Abnormal
# 755            Normal
# 756          Abnormal
# 757      Inconclusive
# 758            Normal
# 759      Inconclusive
# 760          Abnormal
# 761          Abnormal
# 762      Inconclusive
# 763          Abnormal
# 764          Abnormal
# 765      Inconclusive
# 766          Abnormal
# 767      Inconclusive
# 768            Normal
# 769          Abnormal
# 770            Normal
# 771            Normal
# 772          Abnormal
# 773          Abnormal
# 774            Normal
# 775          Abnormal
# 776          Abnormal
# 777            Normal
# 778          Abnormal
# 779          Abnormal
# 780      Inconclusive
# 781      Inconclusive
# 782            Normal
# 783          Abnormal
# 784          Abnormal
# 785          Abnormal
# 786          Abnormal
# 787          Abnormal
# 788      Inconclusive
# 789      Inconclusive
# 790            Normal
# 791      Inconclusive
# 792      Inconclusive
# 793      Inconclusive
# 794          Abnormal
# 795      Inconclusive
# 796          Abnormal
# 797            Normal
# 798          Abnormal
# 799      Inconclusive
# 800          Abnormal
# 801            Normal
# 802            Normal
# 803            Normal
# 804      Inconclusive
# 805            Normal
# 806      Inconclusive
# 807            Normal
# 808      Inconclusive
# 809            Normal
# 810            Normal
# 811      Inconclusive
# 812            Normal
# 813      Inconclusive
# 814          Abnormal
# 815            Normal
# 816            Normal
# 817          Abnormal
# 818      Inconclusive
# 819      Inconclusive
# 820          Abnormal
# 821            Normal
# 822            Normal
# 823      Inconclusive
# 824      Inconclusive
# 825          Abnormal
# 826            Normal
# 827      Inconclusive
# 828            Normal
# 829            Normal
# 830            Normal
# 831      Inconclusive
# 832          Abnormal
# 833      Inconclusive
# 834            Normal
# 835          Abnormal
# 836      Inconclusive
# 837            Normal
# 838          Abnormal
# 839          Abnormal
# 840      Inconclusive
# 841      Inconclusive
# 842          Abnormal
# 843      Inconclusive
# 844          Abnormal
# 845      Inconclusive
# 846            Normal
# 847          Abnormal
# 848          Abnormal
# 849            Normal
# 850      Inconclusive
# 851      Inconclusive
# 852      Inconclusive
# 853            Normal
# 854            Normal
# 855            Normal
# 856      Inconclusive
# 857      Inconclusive
# 858      Inconclusive
# 859            Normal
# 860          Abnormal
# 861          Abnormal
# 862            Normal
# 863            Normal
# 864      Inconclusive
# 865      Inconclusive
# 866          Abnormal
# 867            Normal
# 868            Normal
# 869          Abnormal
# 870          Abnormal
# 871            Normal
# 872            Normal
# 873      Inconclusive
# 874            Normal
# 875          Abnormal
# 876      Inconclusive
# 877          Abnormal
# 878      Inconclusive
# 879          Abnormal
# 880      Inconclusive
# 881      Inconclusive
# 882          Abnormal
# 883          Abnormal
# 884      Inconclusive
# 885      Inconclusive
# 886      Inconclusive
# 887          Abnormal
# 888      Inconclusive
# 889      Inconclusive
# 890            Normal
# 891      Inconclusive
# 892          Abnormal
# 893            Normal
# 894          Abnormal
# 895          Abnormal
# 896            Normal
# 897      Inconclusive
# 898      Inconclusive
# 899            Normal
# 900      Inconclusive
# 901            Normal
# 902          Abnormal
# 903          Abnormal
# 904            Normal
# 905          Abnormal
# 906      Inconclusive
# 907      Inconclusive
# 908          Abnormal
# 909            Normal
# 910            Normal
# 911            Normal
# 912          Abnormal
# 913            Normal
# 914            Normal
# 915          Abnormal
# 916          Abnormal
# 917          Abnormal
# 918          Abnormal
# 919            Normal
# 920      Inconclusive
# 921          Abnormal
# 922      Inconclusive
# 923            Normal
# 924      Inconclusive
# 925      Inconclusive
# 926      Inconclusive
# 927      Inconclusive
# 928      Inconclusive
# 929          Abnormal
# 930      Inconclusive
# 931            Normal
# 932      Inconclusive
# 933      Inconclusive
# 934      Inconclusive
# 935            Normal
# 936            Normal
# 937            Normal
# 938          Abnormal
# 939            Normal
# 940      Inconclusive
# 941          Abnormal
# 942          Abnormal
# 943          Abnormal
# 944          Abnormal
# 945          Abnormal
# 946      Inconclusive
# 947            Normal
# 948          Abnormal
# 949      Inconclusive
# 950          Abnormal
# 951            Normal
# 952          Abnormal
# 953      Inconclusive
# 954          Abnormal
# 955      Inconclusive
# 956          Abnormal
# 957      Inconclusive
# 958            Normal
# 959      Inconclusive
# 960            Normal
# 961            Normal
# 962          Abnormal
# 963          Abnormal
# 964            Normal
# 965          Abnormal
# 966            Normal
# 967          Abnormal
# 968            Normal
# 969          Abnormal
# 970            Normal
# 971            Normal
# 972            Normal
# 973          Abnormal
# 974          Abnormal
# 975          Abnormal
# 976            Normal
# 977          Abnormal
# 978            Normal
# 979      Inconclusive
# 980      Inconclusive
# 981            Normal
# 982      Inconclusive
# 983          Abnormal
# 984      Inconclusive
# 985            Normal
# 986          Abnormal
# 987      Inconclusive
# 988            Normal
# 989            Normal
# 990          Abnormal
# 991            Normal
# 992      Inconclusive
# 993          Abnormal
# 994            Normal
# 995            Normal
# 996          Abnormal
# 997      Inconclusive
# 998      Inconclusive
# 999      Inconclusive
# 1000         Abnormal
# 1001     Inconclusive
# 1002           Normal
# 1003     Inconclusive
# 1004     Inconclusive
# 1005           Normal
# 1006     Inconclusive
# 1007         Abnormal
# 1008         Abnormal
# 1009         Abnormal
# 1010           Normal
# 1011     Inconclusive
# 1012         Abnormal
# 1013     Inconclusive
# 1014     Inconclusive
# 1015     Inconclusive
# 1016     Inconclusive
# 1017         Abnormal
# 1018           Normal
# 1019         Abnormal
# 1020         Abnormal
# 1021     Inconclusive
# 1022     Inconclusive
# 1023         Abnormal
# 1024           Normal
# 1025           Normal
# 1026           Normal
# 1027         Abnormal
# 1028         Abnormal
# 1029         Abnormal
# 1030         Abnormal
# 1031     Inconclusive
# 1032         Abnormal
# 1033         Abnormal
# 1034         Abnormal
# 1035         Abnormal
# 1036     Inconclusive
# 1037         Abnormal
# 1038           Normal
# 1039     Inconclusive
# 1040     Inconclusive
# 1041         Abnormal
# 1042           Normal
# 1043         Abnormal
# 1044         Abnormal
# 1045         Abnormal
# 1046         Abnormal
# 1047         Abnormal
# 1048         Abnormal
# 1049           Normal
# 1050           Normal
# 1051           Normal
# 1052           Normal
# 1053         Abnormal
# 1054         Abnormal
# 1055         Abnormal
# 1056         Abnormal
# 1057         Abnormal
# 1058         Abnormal
# 1059           Normal
# 1060     Inconclusive
# 1061         Abnormal
# 1062         Abnormal
# 1063           Normal
# 1064     Inconclusive
# 1065     Inconclusive
# 1066           Normal
# 1067         Abnormal
# 1068     Inconclusive
# 1069         Abnormal
# 1070         Abnormal
# 1071         Abnormal
# 1072         Abnormal
# 1073           Normal
# 1074         Abnormal
# 1075     Inconclusive
# 1076           Normal
# 1077         Abnormal
# 1078         Abnormal
# 1079           Normal
# 1080     Inconclusive
# 1081         Abnormal
# 1082         Abnormal
# 1083         Abnormal
# 1084           Normal
# 1085         Abnormal
# 1086           Normal
# 1087     Inconclusive
# 1088     Inconclusive
# 1089           Normal
# 1090           Normal
# 1091           Normal
# 1092           Normal
# 1093           Normal
# 1094     Inconclusive
# 1095     Inconclusive
# 1096           Normal
# 1097         Abnormal
# 1098         Abnormal
# 1099           Normal
# 1100           Normal
# 1101     Inconclusive
# 1102         Abnormal
# 1103     Inconclusive
# 1104         Abnormal
# 1105         Abnormal
# 1106         Abnormal
# 1107     Inconclusive
# 1108           Normal
# 1109           Normal
# 1110     Inconclusive
# 1111           Normal
# 1112           Normal
# 1113     Inconclusive
# 1114     Inconclusive
# 1115         Abnormal
# 1116           Normal
# 1117         Abnormal
# 1118           Normal
# 1119           Normal
# 1120           Normal
# 1121           Normal
# 1122         Abnormal
# 1123           Normal
# 1124         Abnormal
# 1125     Inconclusive
# 1126         Abnormal
# 1127     Inconclusive
# 1128           Normal
# 1129         Abnormal
# 1130         Abnormal
# 1131           Normal
# 1132           Normal
# 1133     Inconclusive
# 1134         Abnormal
# 1135           Normal
# 1136     Inconclusive
# 1137           Normal
# 1138           Normal
# 1139           Normal
# 1140     Inconclusive
# 1141         Abnormal
# 1142     Inconclusive
# 1143           Normal
# 1144     Inconclusive
# 1145         Abnormal
# 1146     Inconclusive
# 1147         Abnormal
# 1148           Normal
# 1149           Normal
# 1150           Normal
# 1151     Inconclusive
# 1152     Inconclusive
# 1153         Abnormal
# 1154           Normal
# 1155           Normal
# 1156     Inconclusive
# 1157           Normal
# 1158     Inconclusive
# 1159         Abnormal
# 1160           Normal
# 1161         Abnormal
# 1162         Abnormal
# 1163           Normal
# 1164           Normal
# 1165           Normal
# 1166           Normal
# 1167         Abnormal
# 1168     Inconclusive
# 1169     Inconclusive
# 1170         Abnormal
# 1171     Inconclusive
# 1172         Abnormal
# 1173         Abnormal
# 1174     Inconclusive
# 1175         Abnormal
# 1176         Abnormal
# 1177           Normal
# 1178     Inconclusive
# 1179         Abnormal
# 1180     Inconclusive
# 1181     Inconclusive
# 1182           Normal
# 1183           Normal
# 1184     Inconclusive
# 1185           Normal
# 1186         Abnormal
# 1187     Inconclusive
# 1188           Normal
# 1189     Inconclusive
# 1190         Abnormal
# 1191           Normal
# 1192           Normal
# 1193     Inconclusive
# 1194     Inconclusive
# 1195     Inconclusive
# 1196     Inconclusive
# 1197           Normal
# 1198     Inconclusive
# 1199         Abnormal
# 1200     Inconclusive
# 1201           Normal
# 1202           Normal
# 1203           Normal
# 1204           Normal
# 1205     Inconclusive
# 1206     Inconclusive
# 1207     Inconclusive
# 1208     Inconclusive
# 1209           Normal
# 1210         Abnormal
# 1211         Abnormal
# 1212           Normal
# 1213           Normal
# 1214         Abnormal
# 1215         Abnormal
# 1216           Normal
# 1217         Abnormal
# 1218     Inconclusive
# 1219     Inconclusive
# 1220     Inconclusive
# 1221         Abnormal
# 1222         Abnormal
# 1223           Normal
# 1224     Inconclusive
# 1225           Normal
# 1226           Normal
# 1227           Normal
# 1228           Normal
# 1229         Abnormal
# 1230     Inconclusive
# 1231           Normal
# 1232         Abnormal
# 1233     Inconclusive
# 1234         Abnormal
# 1235           Normal
# 1236           Normal
# 1237         Abnormal
# 1238     Inconclusive
# 1239     Inconclusive
# 1240           Normal
# 1241         Abnormal
# 1242     Inconclusive
# 1243         Abnormal
# 1244         Abnormal
# 1245         Abnormal
# 1246     Inconclusive
# 1247     Inconclusive
# 1248           Normal
# 1249         Abnormal
# 1250         Abnormal
# 1251           Normal
# 1252           Normal
# 1253         Abnormal
# 1254         Abnormal
# 1255     Inconclusive
# 1256         Abnormal
# 1257           Normal
# 1258     Inconclusive
# 1259           Normal
# 1260           Normal
# 1261           Normal
# 1262         Abnormal
# 1263     Inconclusive
# 1264         Abnormal
# 1265         Abnormal
# 1266           Normal
# 1267     Inconclusive
# 1268           Normal
# 1269     Inconclusive
# 1270           Normal
# 1271         Abnormal
# 1272         Abnormal
# 1273           Normal
# 1274     Inconclusive
# 1275         Abnormal
# 1276           Normal
# 1277         Abnormal
# 1278         Abnormal
# 1279         Abnormal
# 1280           Normal
# 1281     Inconclusive
# 1282         Abnormal
# 1283     Inconclusive
# 1284     Inconclusive
# 1285         Abnormal
# 1286     Inconclusive
# 1287         Abnormal
# 1288     Inconclusive
# 1289           Normal
# 1290           Normal
# 1291         Abnormal
# 1292           Normal
# 1293           Normal
# 1294           Normal
# 1295           Normal
# 1296           Normal
# 1297           Normal
# 1298         Abnormal
# 1299           Normal
# 1300         Abnormal
# 1301           Normal
# 1302     Inconclusive
# 1303           Normal
# 1304           Normal
# 1305         Abnormal
# 1306         Abnormal
# 1307     Inconclusive
# 1308         Abnormal
# 1309         Abnormal
# 1310         Abnormal
# 1311     Inconclusive
# 1312     Inconclusive
# 1313         Abnormal
# 1314         Abnormal
# 1315           Normal
# 1316           Normal
# 1317     Inconclusive
# 1318         Abnormal
# 1319           Normal
# 1320         Abnormal
# 1321         Abnormal
# 1322           Normal
# 1323         Abnormal
# 1324         Abnormal
# 1325         Abnormal
# 1326         Abnormal
# 1327         Abnormal
# 1328           Normal
# 1329         Abnormal
# 1330     Inconclusive
# 1331     Inconclusive
# 1332           Normal
# 1333     Inconclusive
# 1334         Abnormal
# 1335           Normal
# 1336         Abnormal
# 1337           Normal
# 1338     Inconclusive
# 1339         Abnormal
# 1340     Inconclusive
# 1341           Normal
# 1342         Abnormal
# 1343           Normal
# 1344         Abnormal
# 1345         Abnormal
# 1346           Normal
# 1347           Normal
# 1348         Abnormal
# 1349         Abnormal
# 1350     Inconclusive
# 1351         Abnormal
# 1352           Normal
# 1353         Abnormal
# 1354           Normal
# 1355     Inconclusive
# 1356     Inconclusive
# 1357     Inconclusive
# 1358           Normal
# 1359     Inconclusive
# 1360     Inconclusive
# 1361         Abnormal
# 1362           Normal
# 1363         Abnormal
# 1364         Abnormal
# 1365         Abnormal
# 1366         Abnormal
# 1367         Abnormal
# 1368           Normal
# 1369     Inconclusive
# 1370           Normal
# 1371           Normal
# 1372           Normal
# 1373         Abnormal
# 1374     Inconclusive
# 1375         Abnormal
# 1376         Abnormal
# 1377           Normal
# 1378         Abnormal
# 1379         Abnormal
# 1380         Abnormal
# 1381           Normal
# 1382     Inconclusive
# 1383     Inconclusive
# 1384         Abnormal
# 1385     Inconclusive
# 1386     Inconclusive
# 1387     Inconclusive
# 1388           Normal
# 1389         Abnormal
# 1390           Normal
# 1391           Normal
# 1392     Inconclusive
# 1393         Abnormal
# 1394         Abnormal
# 1395           Normal
# 1396           Normal
# 1397     Inconclusive
# 1398     Inconclusive
# 1399         Abnormal
# 1400     Inconclusive
# 1401           Normal
# 1402           Normal
# 1403     Inconclusive
# 1404           Normal
# 1405         Abnormal
# 1406     Inconclusive
# 1407     Inconclusive
# 1408     Inconclusive
# 1409     Inconclusive
# 1410     Inconclusive
# 1411         Abnormal
# 1412         Abnormal
# 1413         Abnormal
# 1414           Normal
# 1415         Abnormal
# 1416     Inconclusive
# 1417     Inconclusive
# 1418     Inconclusive
# 1419         Abnormal
# 1420         Abnormal
# 1421         Abnormal
# 1422         Abnormal
# 1423     Inconclusive
# 1424           Normal
# 1425     Inconclusive
# 1426     Inconclusive
# 1427     Inconclusive
# 1428         Abnormal
# 1429           Normal
# 1430           Normal
# 1431         Abnormal
# 1432         Abnormal
# 1433         Abnormal
# 1434     Inconclusive
# 1435     Inconclusive
# 1436         Abnormal
# 1437         Abnormal
# 1438           Normal
# 1439           Normal
# 1440     Inconclusive
# 1441         Abnormal
# 1442         Abnormal
# 1443     Inconclusive
# 1444           Normal
# 1445     Inconclusive
# 1446     Inconclusive
# 1447           Normal
# 1448           Normal
# 1449     Inconclusive
# 1450         Abnormal
# 1451         Abnormal
# 1452         Abnormal
# 1453         Abnormal
# 1454         Abnormal
# 1455     Inconclusive
# 1456           Normal
# 1457           Normal
# 1458         Abnormal
# 1459     Inconclusive
# 1460         Abnormal
# 1461           Normal
# 1462     Inconclusive
# 1463     Inconclusive
# 1464         Abnormal
# 1465     Inconclusive
# 1466           Normal
# 1467           Normal
# 1468     Inconclusive
# 1469         Abnormal
# 1470         Abnormal
# 1471           Normal
# 1472     Inconclusive
# 1473         Abnormal
# 1474           Normal
# 1475           Normal
# 1476         Abnormal
# 1477           Normal
# 1478           Normal
# 1479     Inconclusive
# 1480           Normal
# 1481         Abnormal
# 1482     Inconclusive
# 1483         Abnormal
# 1484     Inconclusive
# 1485           Normal
# 1486           Normal
# 1487     Inconclusive
# 1488           Normal
# 1489     Inconclusive
# 1490     Inconclusive
# 1491           Normal
# 1492     Inconclusive
# 1493         Abnormal
# 1494         Abnormal
# 1495     Inconclusive
# 1496     Inconclusive
# 1497           Normal
# 1498         Abnormal
# 1499     Inconclusive
# 1500     Inconclusive
# 1501         Abnormal
# 1502     Inconclusive
# 1503           Normal
# 1504         Abnormal
# 1505     Inconclusive
# 1506           Normal
# 1507     Inconclusive
# 1508         Abnormal
# 1509           Normal
# 1510           Normal
# 1511     Inconclusive
# 1512     Inconclusive
# 1513         Abnormal
# 1514     Inconclusive
# 1515         Abnormal
# 1516           Normal
# 1517         Abnormal
# 1518     Inconclusive
# 1519           Normal
# 1520         Abnormal
# 1521     Inconclusive
# 1522         Abnormal
# 1523     Inconclusive
# 1524           Normal
# 1525           Normal
# 1526         Abnormal
# 1527     Inconclusive
# 1528           Normal
# 1529     Inconclusive
# 1530         Abnormal
# 1531         Abnormal
# 1532     Inconclusive
# 1533           Normal
# 1534         Abnormal
# 1535         Abnormal
# 1536         Abnormal
# 1537         Abnormal
# 1538     Inconclusive
# 1539         Abnormal
# 1540           Normal
# 1541     Inconclusive
# 1542           Normal
# 1543     Inconclusive
# 1544           Normal
# 1545     Inconclusive
# 1546           Normal
# 1547           Normal
# 1548           Normal
# 1549         Abnormal
# 1550         Abnormal
# 1551           Normal
# 1552     Inconclusive
# 1553     Inconclusive
# 1554         Abnormal
# 1555         Abnormal
# 1556           Normal
# 1557           Normal
# 1558     Inconclusive
# 1559     Inconclusive
# 1560     Inconclusive
# 1561           Normal
# 1562     Inconclusive
# 1563         Abnormal
# 1564     Inconclusive
# 1565         Abnormal
# 1566     Inconclusive
# 1567           Normal
# 1568         Abnormal
# 1569         Abnormal
# 1570         Abnormal
# 1571           Normal
# 1572     Inconclusive
# 1573           Normal
# 1574     Inconclusive
# 1575         Abnormal
# 1576         Abnormal
# 1577     Inconclusive
# 1578     Inconclusive
# 1579     Inconclusive
# 1580           Normal
# 1581         Abnormal
# 1582           Normal
# 1583     Inconclusive
# 1584           Normal
# 1585         Abnormal
# 1586           Normal
# 1587         Abnormal
# 1588     Inconclusive
# 1589     Inconclusive
# 1590           Normal
# 1591         Abnormal
# 1592     Inconclusive
# 1593     Inconclusive
# 1594     Inconclusive
# 1595         Abnormal
# 1596     Inconclusive
# 1597     Inconclusive
# 1598     Inconclusive
# 1599     Inconclusive
# 1600         Abnormal
# 1601           Normal
# 1602         Abnormal
# 1603     Inconclusive
# 1604           Normal
# 1605         Abnormal
# 1606     Inconclusive
# 1607           Normal
# 1608     Inconclusive
# 1609     Inconclusive
# 1610         Abnormal
# 1611           Normal
# 1612     Inconclusive
# 1613         Abnormal
# 1614         Abnormal
# 1615     Inconclusive
# 1616     Inconclusive
# 1617           Normal
# 1618         Abnormal
# 1619           Normal
# 1620     Inconclusive
# 1621           Normal
# 1622           Normal
# 1623         Abnormal
# 1624         Abnormal
# 1625         Abnormal
# 1626     Inconclusive
# 1627         Abnormal
# 1628         Abnormal
# 1629     Inconclusive
# 1630           Normal
# 1631         Abnormal
# 1632           Normal
# 1633         Abnormal
# 1634           Normal
# 1635         Abnormal
# 1636         Abnormal
# 1637     Inconclusive
# 1638     Inconclusive
# 1639         Abnormal
# 1640     Inconclusive
# 1641           Normal
# 1642           Normal
# 1643         Abnormal
# 1644         Abnormal
# 1645           Normal
# 1646         Abnormal
# 1647         Abnormal
# 1648         Abnormal
# 1649           Normal
# 1650         Abnormal
# 1651         Abnormal
# 1652     Inconclusive
# 1653         Abnormal
# 1654         Abnormal
# 1655           Normal
# 1656         Abnormal
# 1657     Inconclusive
# 1658     Inconclusive
# 1659           Normal
# 1660           Normal
# 1661         Abnormal
# 1662           Normal
# 1663         Abnormal
# 1664     Inconclusive
# 1665           Normal
# 1666     Inconclusive
# 1667           Normal
# 1668     Inconclusive
# 1669           Normal
# 1670           Normal
# 1671           Normal
# 1672     Inconclusive
# 1673         Abnormal
# 1674           Normal
# 1675     Inconclusive
# 1676           Normal
# 1677         Abnormal
# 1678     Inconclusive
# 1679           Normal
# 1680         Abnormal
# 1681         Abnormal
# 1682         Abnormal
# 1683         Abnormal
# 1684           Normal
# 1685     Inconclusive
# 1686     Inconclusive
# 1687         Abnormal
# 1688     Inconclusive
# 1689         Abnormal
# 1690     Inconclusive
# 1691     Inconclusive
# 1692     Inconclusive
# 1693     Inconclusive
# 1694         Abnormal
# 1695     Inconclusive
# 1696         Abnormal
# 1697           Normal
# 1698         Abnormal
# 1699     Inconclusive
# 1700     Inconclusive
# 1701           Normal
# 1702           Normal
# 1703     Inconclusive
# 1704           Normal
# 1705           Normal
# 1706           Normal
# 1707         Abnormal
# 1708     Inconclusive
# 1709         Abnormal
# 1710           Normal
# 1711         Abnormal
# 1712     Inconclusive
# 1713         Abnormal
# 1714           Normal
# 1715     Inconclusive
# 1716     Inconclusive
# 1717     Inconclusive
# 1718     Inconclusive
# 1719     Inconclusive
# 1720         Abnormal
# 1721           Normal
# 1722     Inconclusive
# 1723           Normal
# 1724         Abnormal
# 1725         Abnormal
# 1726         Abnormal
# 1727           Normal
# 1728           Normal
# 1729     Inconclusive
# 1730         Abnormal
# 1731           Normal
# 1732           Normal
# 1733         Abnormal
# 1734           Normal
# 1735         Abnormal
# 1736           Normal
# 1737     Inconclusive
# 1738           Normal
# 1739     Inconclusive
# 1740         Abnormal
# 1741         Abnormal
# 1742     Inconclusive
# 1743     Inconclusive
# 1744         Abnormal
# 1745         Abnormal
# 1746     Inconclusive
# 1747     Inconclusive
# 1748         Abnormal
# 1749           Normal
# 1750     Inconclusive
# 1751         Abnormal
# 1752     Inconclusive
# 1753           Normal
# 1754     Inconclusive
# 1755         Abnormal
# 1756         Abnormal
# 1757     Inconclusive
# 1758         Abnormal
# 1759     Inconclusive
# 1760     Inconclusive
# 1761     Inconclusive
# 1762         Abnormal
# 1763     Inconclusive
# 1764         Abnormal
# 1765     Inconclusive
# 1766         Abnormal
# 1767           Normal
# 1768     Inconclusive
# 1769         Abnormal
# 1770         Abnormal
# 1771           Normal
# 1772     Inconclusive
# 1773           Normal
# 1774         Abnormal
# 1775     Inconclusive
# 1776           Normal
# 1777           Normal
# 1778           Normal
# 1779           Normal
# 1780     Inconclusive
# 1781         Abnormal
# 1782     Inconclusive
# 1783         Abnormal
# 1784           Normal
# 1785     Inconclusive
# 1786           Normal
# 1787           Normal
# 1788           Normal
# 1789         Abnormal
# 1790         Abnormal
# 1791     Inconclusive
# 1792           Normal
# 1793           Normal
# 1794           Normal
# 1795     Inconclusive
# 1796           Normal
# 1797     Inconclusive
# 1798           Normal
# 1799           Normal
# 1800     Inconclusive
# 1801         Abnormal
# 1802           Normal
# 1803           Normal
# 1804           Normal
# 1805         Abnormal
# 1806         Abnormal
# 1807     Inconclusive
# 1808           Normal
# 1809           Normal
# 1810         Abnormal
# 1811           Normal
# 1812     Inconclusive
# 1813     Inconclusive
# 1814     Inconclusive
# 1815         Abnormal
# 1816         Abnormal
# 1817     Inconclusive
# 1818         Abnormal
# 1819           Normal
# 1820           Normal
# 1821     Inconclusive
# 1822     Inconclusive
# 1823         Abnormal
# 1824         Abnormal
# 1825         Abnormal
# 1826           Normal
# 1827         Abnormal
# 1828         Abnormal
# 1829         Abnormal
# 1830         Abnormal
# 1831         Abnormal
# 1832         Abnormal
# 1833         Abnormal
# 1834         Abnormal
# 1835     Inconclusive
# 1836         Abnormal
# 1837     Inconclusive
# 1838     Inconclusive
# 1839         Abnormal
# 1840           Normal
# 1841     Inconclusive
# 1842     Inconclusive
# 1843         Abnormal
# 1844           Normal
# 1845         Abnormal
# 1846         Abnormal
# 1847           Normal
# 1848           Normal
# 1849     Inconclusive
# 1850         Abnormal
# 1851     Inconclusive
# 1852         Abnormal
# 1853     Inconclusive
# 1854           Normal
# 1855           Normal
# 1856           Normal
# 1857           Normal
# 1858           Normal
# 1859           Normal
# 1860     Inconclusive
# 1861           Normal
# 1862           Normal
# 1863           Normal
# 1864           Normal
# 1865         Abnormal
# 1866     Inconclusive
# 1867           Normal
# 1868         Abnormal
# 1869           Normal
# 1870     Inconclusive
# 1871           Normal
# 1872         Abnormal
# 1873           Normal
# 1874         Abnormal
# 1875           Normal
# 1876     Inconclusive
# 1877     Inconclusive
# 1878         Abnormal
# 1879     Inconclusive
# 1880         Abnormal
# 1881     Inconclusive
# 1882     Inconclusive
# 1883     Inconclusive
# 1884           Normal
# 1885           Normal
# 1886         Abnormal
# 1887           Normal
# 1888     Inconclusive
# 1889     Inconclusive
# 1890         Abnormal
# 1891     Inconclusive
# 1892           Normal
# 1893     Inconclusive
# 1894         Abnormal
# 1895           Normal
# 1896         Abnormal
# 1897     Inconclusive
# 1898     Inconclusive
# 1899         Abnormal
# 1900           Normal
# 1901         Abnormal
# 1902     Inconclusive
# 1903     Inconclusive
# 1904     Inconclusive
# 1905     Inconclusive
# 1906         Abnormal
# 1907           Normal
# 1908           Normal
# 1909         Abnormal
# 1910           Normal
# 1911     Inconclusive
# 1912     Inconclusive
# 1913           Normal
# 1914           Normal
# 1915     Inconclusive
# 1916           Normal
# 1917     Inconclusive
# 1918         Abnormal
# 1919           Normal
# 1920     Inconclusive
# 1921         Abnormal
# 1922     Inconclusive
# 1923         Abnormal
# 1924         Abnormal
# 1925           Normal
# 1926     Inconclusive
# 1927           Normal
# 1928           Normal
# 1929     Inconclusive
# 1930     Inconclusive
# 1931         Abnormal
# 1932     Inconclusive
# 1933         Abnormal
# 1934           Normal
# 1935     Inconclusive
# 1936     Inconclusive
# 1937         Abnormal
# 1938     Inconclusive
# 1939           Normal
# 1940         Abnormal
# 1941           Normal
# 1942           Normal
# 1943           Normal
# 1944         Abnormal
# 1945           Normal
# 1946     Inconclusive
# 1947     Inconclusive
# 1948         Abnormal
# 1949         Abnormal
# 1950     Inconclusive
# 1951           Normal
# 1952     Inconclusive
# 1953           Normal
# 1954     Inconclusive
# 1955           Normal
# 1956         Abnormal
# 1957     Inconclusive
# 1958     Inconclusive
# 1959         Abnormal
# 1960         Abnormal
# 1961         Abnormal
# 1962         Abnormal
# 1963         Abnormal
# 1964     Inconclusive
# 1965         Abnormal
# 1966     Inconclusive
# 1967           Normal
# 1968     Inconclusive
# 1969           Normal
# 1970           Normal
# 1971         Abnormal
# 1972     Inconclusive
# 1973     Inconclusive
# 1974         Abnormal
# 1975           Normal
# 1976     Inconclusive
# 1977         Abnormal
# 1978     Inconclusive
# 1979         Abnormal
# 1980           Normal
# 1981           Normal
# 1982         Abnormal
# 1983           Normal
# 1984         Abnormal
# 1985     Inconclusive
# 1986         Abnormal
# 1987           Normal
# 1988         Abnormal
# 1989         Abnormal
# 1990         Abnormal
# 1991           Normal
# 1992     Inconclusive
# 1993           Normal
# 1994         Abnormal
# 1995         Abnormal
# 1996           Normal
# 1997           Normal
# 1998     Inconclusive
# 1999         Abnormal
# 2000     Inconclusive
# 2001           Normal
# 2002     Inconclusive
# 2003           Normal
# 2004     Inconclusive
# 2005     Inconclusive
# 2006     Inconclusive
# 2007         Abnormal
# 2008           Normal
# 2009           Normal
# 2010     Inconclusive
# 2011           Normal
# 2012     Inconclusive
# 2013     Inconclusive
# 2014     Inconclusive
# 2015           Normal
# 2016     Inconclusive
# 2017           Normal
# 2018           Normal
# 2019     Inconclusive
# 2020     Inconclusive
# 2021           Normal
# 2022         Abnormal
# 2023           Normal
# 2024           Normal
# 2025           Normal
# 2026           Normal
# 2027     Inconclusive
# 2028           Normal
# 2029     Inconclusive
# 2030         Abnormal
# 2031     Inconclusive
# 2032     Inconclusive
# 2033     Inconclusive
# 2034           Normal
# 2035     Inconclusive
# 2036     Inconclusive
# 2037         Abnormal
# 2038     Inconclusive
# 2039           Normal
# 2040         Abnormal
# 2041     Inconclusive
# 2042           Normal
# 2043           Normal
# 2044     Inconclusive
# 2045     Inconclusive
# 2046         Abnormal
# 2047     Inconclusive
# 2048     Inconclusive
# 2049         Abnormal
# 2050           Normal
# 2051     Inconclusive
# 2052     Inconclusive
# 2053     Inconclusive
# 2054           Normal
# 2055         Abnormal
# 2056         Abnormal
# 2057         Abnormal
# 2058           Normal
# 2059         Abnormal
# 2060           Normal
# 2061         Abnormal
# 2062         Abnormal
# 2063         Abnormal
# 2064           Normal
# 2065     Inconclusive
# 2066     Inconclusive
# 2067           Normal
# 2068         Abnormal
# 2069         Abnormal
# 2070     Inconclusive
# 2071         Abnormal
# 2072     Inconclusive
# 2073     Inconclusive
# 2074     Inconclusive
# 2075         Abnormal
# 2076         Abnormal
# 2077         Abnormal
# 2078         Abnormal
# 2079     Inconclusive
# 2080         Abnormal
# 2081     Inconclusive
# 2082           Normal
# 2083         Abnormal
# 2084     Inconclusive
# 2085           Normal
# 2086     Inconclusive
# 2087           Normal
# 2088     Inconclusive
# 2089         Abnormal
# 2090           Normal
# 2091         Abnormal
# 2092         Abnormal
# 2093         Abnormal
# 2094     Inconclusive
# 2095           Normal
# 2096     Inconclusive
# 2097           Normal
# 2098           Normal
# 2099           Normal
# 2100         Abnormal
# 2101           Normal
# 2102         Abnormal
# 2103         Abnormal
# 2104           Normal
# 2105         Abnormal
# 2106           Normal
# 2107           Normal
# 2108     Inconclusive
# 2109     Inconclusive
# 2110         Abnormal
# 2111           Normal
# 2112     Inconclusive
# 2113     Inconclusive
# 2114         Abnormal
# 2115     Inconclusive
# 2116           Normal
# 2117         Abnormal
# 2118         Abnormal
# 2119           Normal
# 2120     Inconclusive
# 2121           Normal
# 2122     Inconclusive
# 2123         Abnormal
# 2124         Abnormal
# 2125     Inconclusive
# 2126           Normal
# 2127         Abnormal
# 2128         Abnormal
# 2129     Inconclusive
# 2130           Normal
# 2131         Abnormal
# 2132           Normal
# 2133     Inconclusive
# 2134         Abnormal
# 2135           Normal
# 2136           Normal
# 2137     Inconclusive
# 2138           Normal
# 2139     Inconclusive
# 2140           Normal
# 2141         Abnormal
# 2142           Normal
# 2143         Abnormal
# 2144           Normal
# 2145           Normal
# 2146           Normal
# 2147     Inconclusive
# 2148         Abnormal
# 2149           Normal
# 2150         Abnormal
# 2151           Normal
# 2152           Normal
# 2153     Inconclusive
# 2154     Inconclusive
# 2155           Normal
# 2156     Inconclusive
# 2157           Normal
# 2158     Inconclusive
# 2159     Inconclusive
# 2160           Normal
# 2161           Normal
# 2162         Abnormal
# 2163           Normal
# 2164         Abnormal
# 2165     Inconclusive
# 2166     Inconclusive
# 2167     Inconclusive
# 2168           Normal
# 2169           Normal
# 2170           Normal
# 2171         Abnormal
# 2172           Normal
# 2173         Abnormal
# 2174         Abnormal
# 2175     Inconclusive
# 2176     Inconclusive
# 2177           Normal
# 2178     Inconclusive
# 2179           Normal
# 2180         Abnormal
# ...
# 49275          Normal
# 49276    Inconclusive
# 49277        Abnormal
# 49278        Abnormal
# 49279        Abnormal
# 49280          Normal
# 49281        Abnormal
# 49282        Abnormal
# 49283          Normal
# 49284    Inconclusive
# 49285    Inconclusive
# 49286          Normal
# 49287    Inconclusive
# 49288        Abnormal
# 49289    Inconclusive
# 49290    Inconclusive
# 49291          Normal
# 49292        Abnormal
# 49293          Normal
# 49294    Inconclusive
# 49295    Inconclusive
# 49296        Abnormal
# 49297    Inconclusive
# 49298    Inconclusive
# 49299        Abnormal
# 49300    Inconclusive
# 49301          Normal
# 49302    Inconclusive
# 49303          Normal
# 49304          Normal
# 49305    Inconclusive
# 49306          Normal
# 49307          Normal
# 49308          Normal
# 49309          Normal
# 49310        Abnormal
# 49311        Abnormal
# 49312          Normal
# 49313        Abnormal
# 49314          Normal
# 49315        Abnormal
# 49316          Normal
# 49317    Inconclusive
# 49318          Normal
# 49319          Normal
# 49320          Normal
# 49321        Abnormal
# 49322          Normal
# 49323    Inconclusive
# 49324    Inconclusive
# 49325        Abnormal
# 49326          Normal
# 49327    Inconclusive
# 49328    Inconclusive
# 49329          Normal
# 49330        Abnormal
# 49331    Inconclusive
# 49332          Normal
# 49333    Inconclusive
# 49334        Abnormal
# 49335        Abnormal
# 49336        Abnormal
# 49337    Inconclusive
# 49338        Abnormal
# 49339    Inconclusive
# 49340        Abnormal
# 49341    Inconclusive
# 49342    Inconclusive
# 49343          Normal
# 49344          Normal
# 49345    Inconclusive
# 49346        Abnormal
# 49347    Inconclusive
# 49348          Normal
# 49349          Normal
# 49350        Abnormal
# 49351    Inconclusive
# 49352        Abnormal
# 49353        Abnormal
# 49354    Inconclusive
# 49355          Normal
# 49356        Abnormal
# 49357          Normal
# 49358          Normal
# 49359          Normal
# 49360        Abnormal
# 49361          Normal
# 49362          Normal
# 49363        Abnormal
# 49364          Normal
# 49365          Normal
# 49366          Normal
# 49367          Normal
# 49368        Abnormal
# 49369          Normal
# 49370          Normal
# 49371    Inconclusive
# 49372        Abnormal
# 49373          Normal
# 49374          Normal
# 49375    Inconclusive
# 49376          Normal
# 49377        Abnormal
# 49378    Inconclusive
# 49379        Abnormal
# 49380          Normal
# 49381    Inconclusive
# 49382    Inconclusive
# 49383          Normal
# 49384        Abnormal
# 49385        Abnormal
# 49386        Abnormal
# 49387    Inconclusive
# 49388    Inconclusive
# 49389        Abnormal
# 49390        Abnormal
# 49391          Normal
# 49392          Normal
# 49393    Inconclusive
# 49394          Normal
# 49395    Inconclusive
# 49396    Inconclusive
# 49397        Abnormal
# 49398          Normal
# 49399        Abnormal
# 49400          Normal
# 49401    Inconclusive
# 49402    Inconclusive
# 49403        Abnormal
# 49404        Abnormal
# 49405        Abnormal
# 49406        Abnormal
# 49407        Abnormal
# 49408          Normal
# 49409          Normal
# 49410          Normal
# 49411    Inconclusive
# 49412          Normal
# 49413    Inconclusive
# 49414        Abnormal
# 49415    Inconclusive
# 49416        Abnormal
# 49417          Normal
# 49418    Inconclusive
# 49419        Abnormal
# 49420        Abnormal
# 49421        Abnormal
# 49422        Abnormal
# 49423          Normal
# 49424    Inconclusive
# 49425          Normal
# 49426          Normal
# 49427          Normal
# 49428    Inconclusive
# 49429    Inconclusive
# 49430          Normal
# 49431        Abnormal
# 49432    Inconclusive
# 49433    Inconclusive
# 49434    Inconclusive
# 49435    Inconclusive
# 49436    Inconclusive
# 49437    Inconclusive
# 49438    Inconclusive
# 49439    Inconclusive
# 49440          Normal
# 49441    Inconclusive
# 49442          Normal
# 49443          Normal
# 49444          Normal
# 49445          Normal
# 49446          Normal
# 49447          Normal
# 49448    Inconclusive
# 49449    Inconclusive
# 49450    Inconclusive
# 49451    Inconclusive
# 49452        Abnormal
# 49453    Inconclusive
# 49454        Abnormal
# 49455        Abnormal
# 49456        Abnormal
# 49457    Inconclusive
# 49458          Normal
# 49459        Abnormal
# 49460          Normal
# 49461        Abnormal
# 49462        Abnormal
# 49463        Abnormal
# 49464        Abnormal
# 49465        Abnormal
# 49466        Abnormal
# 49467          Normal
# 49468          Normal
# 49469    Inconclusive
# 49470    Inconclusive
# 49471          Normal
# 49472    Inconclusive
# 49473        Abnormal
# 49474        Abnormal
# 49475          Normal
# 49476    Inconclusive
# 49477        Abnormal
# 49478    Inconclusive
# 49479          Normal
# 49480        Abnormal
# 49481        Abnormal
# 49482          Normal
# 49483          Normal
# 49484    Inconclusive
# 49485        Abnormal
# 49486    Inconclusive
# 49487    Inconclusive
# 49488        Abnormal
# 49489          Normal
# 49490        Abnormal
# 49491          Normal
# 49492    Inconclusive
# 49493          Normal
# 49494        Abnormal
# 49495          Normal
# 49496    Inconclusive
# 49497          Normal
# 49498          Normal
# 49499        Abnormal
# 49500    Inconclusive
# 49501        Abnormal
# 49502    Inconclusive
# 49503        Abnormal
# 49504    Inconclusive
# 49505          Normal
# 49506          Normal
# 49507        Abnormal
# 49508    Inconclusive
# 49509        Abnormal
# 49510        Abnormal
# 49511        Abnormal
# 49512          Normal
# 49513          Normal
# 49514    Inconclusive
# 49515        Abnormal
# 49516          Normal
# 49517    Inconclusive
# 49518        Abnormal
# 49519          Normal
# 49520        Abnormal
# 49521    Inconclusive
# 49522          Normal
# 49523        Abnormal
# 49524          Normal
# 49525        Abnormal
# 49526          Normal
# 49527    Inconclusive
# 49528    Inconclusive
# 49529    Inconclusive
# 49530          Normal
# 49531    Inconclusive
# 49532    Inconclusive
# 49533    Inconclusive
# 49534          Normal
# 49535        Abnormal
# 49536        Abnormal
# 49537    Inconclusive
# 49538          Normal
# 49539    Inconclusive
# 49540          Normal
# 49541        Abnormal
# 49542    Inconclusive
# 49543        Abnormal
# 49544    Inconclusive
# 49545        Abnormal
# 49546        Abnormal
# 49547          Normal
# 49548    Inconclusive
# 49549        Abnormal
# 49550          Normal
# 49551        Abnormal
# 49552        Abnormal
# 49553        Abnormal
# 49554          Normal
# 49555        Abnormal
# 49556          Normal
# 49557    Inconclusive
# 49558    Inconclusive
# 49559        Abnormal
# 49560          Normal
# 49561        Abnormal
# 49562          Normal
# 49563        Abnormal
# 49564    Inconclusive
# 49565          Normal
# 49566        Abnormal
# 49567        Abnormal
# 49568        Abnormal
# 49569        Abnormal
# 49570          Normal
# 49571          Normal
# 49572    Inconclusive
# 49573        Abnormal
# 49574    Inconclusive
# 49575          Normal
# 49576        Abnormal
# 49577    Inconclusive
# 49578    Inconclusive
# 49579        Abnormal
# 49580    Inconclusive
# 49581          Normal
# 49582    Inconclusive
# 49583          Normal
# 49584        Abnormal
# 49585        Abnormal
# 49586          Normal
# 49587        Abnormal
# 49588    Inconclusive
# 49589          Normal
# 49590    Inconclusive
# 49591        Abnormal
# 49592          Normal
# 49593        Abnormal
# 49594        Abnormal
# 49595        Abnormal
# 49596          Normal
# 49597          Normal
# 49598          Normal
# 49599          Normal
# 49600        Abnormal
# 49601        Abnormal
# 49602    Inconclusive
# 49603    Inconclusive
# 49604          Normal
# 49605        Abnormal
# 49606        Abnormal
# 49607        Abnormal
# 49608    Inconclusive
# 49609        Abnormal
# 49610          Normal
# 49611    Inconclusive
# 49612    Inconclusive
# 49613        Abnormal
# 49614    Inconclusive
# 49615        Abnormal
# 49616        Abnormal
# 49617        Abnormal
# 49618        Abnormal
# 49619        Abnormal
# 49620    Inconclusive
# 49621    Inconclusive
# 49622          Normal
# 49623    Inconclusive
# 49624        Abnormal
# 49625    Inconclusive
# 49626          Normal
# 49627          Normal
# 49628    Inconclusive
# 49629        Abnormal
# 49630    Inconclusive
# 49631    Inconclusive
# 49632    Inconclusive
# 49633    Inconclusive
# 49634        Abnormal
# 49635    Inconclusive
# 49636        Abnormal
# 49637    Inconclusive
# 49638    Inconclusive
# 49639        Abnormal
# 49640        Abnormal
# 49641        Abnormal
# 49642        Abnormal
# 49643    Inconclusive
# 49644        Abnormal
# 49645    Inconclusive
# 49646          Normal
# 49647    Inconclusive
# 49648          Normal
# 49649        Abnormal
# 49650    Inconclusive
# 49651          Normal
# 49652    Inconclusive
# 49653    Inconclusive
# 49654        Abnormal
# 49655    Inconclusive
# 49656    Inconclusive
# 49657          Normal
# 49658          Normal
# 49659    Inconclusive
# 49660    Inconclusive
# 49661          Normal
# 49662    Inconclusive
# 49663    Inconclusive
# 49664          Normal
# 49665    Inconclusive
# 49666          Normal
# 49667          Normal
# 49668        Abnormal
# 49669          Normal
# 49670    Inconclusive
# 49671        Abnormal
# 49672        Abnormal
# 49673    Inconclusive
# 49674    Inconclusive
# 49675    Inconclusive
# 49676    Inconclusive
# 49677    Inconclusive
# 49678    Inconclusive
# 49679        Abnormal
# 49680          Normal
# 49681        Abnormal
# 49682          Normal
# 49683        Abnormal
# 49684        Abnormal
# 49685    Inconclusive
# 49686        Abnormal
# 49687    Inconclusive
# 49688          Normal
# 49689          Normal
# 49690    Inconclusive
# 49691    Inconclusive
# 49692          Normal
# 49693    Inconclusive
# 49694        Abnormal
# 49695    Inconclusive
# 49696    Inconclusive
# 49697        Abnormal
# 49698          Normal
# 49699          Normal
# 49700        Abnormal
# 49701    Inconclusive
# 49702        Abnormal
# 49703          Normal
# 49704        Abnormal
# 49705        Abnormal
# 49706    Inconclusive
# 49707          Normal
# 49708    Inconclusive
# 49709          Normal
# 49710    Inconclusive
# 49711          Normal
# 49712    Inconclusive
# 49713        Abnormal
# 49714        Abnormal
# 49715    Inconclusive
# 49716        Abnormal
# 49717        Abnormal
# 49718        Abnormal
# 49719          Normal
# 49720        Abnormal
# 49721          Normal
# 49722    Inconclusive
# 49723        Abnormal
# 49724        Abnormal
# 49725        Abnormal
# 49726          Normal
# 49727        Abnormal
# 49728    Inconclusive
# 49729        Abnormal
# 49730          Normal
# 49731    Inconclusive
# 49732          Normal
# 49733          Normal
# 49734          Normal
# 49735        Abnormal
# 49736    Inconclusive
# 49737          Normal
# 49738        Abnormal
# 49739    Inconclusive
# 49740        Abnormal
# 49741          Normal
# 49742    Inconclusive
# 49743    Inconclusive
# 49744    Inconclusive
# 49745          Normal
# 49746    Inconclusive
# 49747    Inconclusive
# 49748          Normal
# 49749        Abnormal
# 49750          Normal
# 49751    Inconclusive
# 49752          Normal
# 49753        Abnormal
# 49754    Inconclusive
# 49755        Abnormal
# 49756        Abnormal
# 49757    Inconclusive
# 49758    Inconclusive
# 49759    Inconclusive
# 49760          Normal
# 49761    Inconclusive
# 49762    Inconclusive
# 49763        Abnormal
# 49764        Abnormal
# 49765        Abnormal
# 49766          Normal
# 49767    Inconclusive
# 49768        Abnormal
# 49769          Normal
# 49770        Abnormal
# 49771    Inconclusive
# 49772          Normal
# 49773        Abnormal
# 49774          Normal
# 49775        Abnormal
# 49776    Inconclusive
# 49777          Normal
# 49778          Normal
# 49779          Normal
# 49780    Inconclusive
# 49781    Inconclusive
# 49782    Inconclusive
# 49783        Abnormal
# 49784        Abnormal
# 49785    Inconclusive
# 49786    Inconclusive
# 49787    Inconclusive
# 49788        Abnormal
# 49789          Normal
# 49790    Inconclusive
# 49791    Inconclusive
# 49792    Inconclusive
# 49793    Inconclusive
# 49794        Abnormal
# 49795        Abnormal
# 49796        Abnormal
# 49797    Inconclusive
# 49798          Normal
# 49799          Normal
# 49800    Inconclusive
# 49801    Inconclusive
# 49802        Abnormal
# 49803        Abnormal
# 49804    Inconclusive
# 49805    Inconclusive
# 49806        Abnormal
# 49807    Inconclusive
# 49808    Inconclusive
# 49809        Abnormal
# 49810          Normal
# 49811        Abnormal
# 49812        Abnormal
# 49813    Inconclusive
# 49814        Abnormal
# 49815    Inconclusive
# 49816        Abnormal
# 49817        Abnormal
# 49818        Abnormal
# 49819    Inconclusive
# 49820          Normal
# 49821    Inconclusive
# 49822    Inconclusive
# 49823    Inconclusive
# 49824    Inconclusive
# 49825        Abnormal
# 49826    Inconclusive
# 49827    Inconclusive
# 49828    Inconclusive
# 49829          Normal
# 49830        Abnormal
# 49831    Inconclusive
# 49832        Abnormal
# 49833          Normal
# 49834        Abnormal
# 49835    Inconclusive
# 49836          Normal
# 49837    Inconclusive
# 49838          Normal
# 49839          Normal
# 49840          Normal
# 49841    Inconclusive
# 49842        Abnormal
# 49843    Inconclusive
# 49844    Inconclusive
# 49845        Abnormal
# 49846    Inconclusive
# 49847    Inconclusive
# 49848          Normal
# 49849    Inconclusive
# 49850    Inconclusive
# 49851          Normal
# 49852    Inconclusive
# 49853          Normal
# 49854        Abnormal
# 49855    Inconclusive
# 49856          Normal
# 49857    Inconclusive
# 49858    Inconclusive
# 49859          Normal
# 49860          Normal
# 49861        Abnormal
# 49862          Normal
# 49863          Normal
# 49864          Normal
# 49865    Inconclusive
# 49866        Abnormal
# 49867        Abnormal
# 49868          Normal
# 49869        Abnormal
# 49870        Abnormal
# 49871        Abnormal
# 49872        Abnormal
# 49873        Abnormal
# 49874    Inconclusive
# 49875    Inconclusive
# 49876          Normal
# 49877          Normal
# 49878        Abnormal
# 49879    Inconclusive
# 49880    Inconclusive
# 49881    Inconclusive
# 49882    Inconclusive
# 49883        Abnormal
# 49884          Normal
# 49885        Abnormal
# 49886        Abnormal
# 49887        Abnormal
# 49888          Normal
# 49889        Abnormal
# 49890        Abnormal
# 49891    Inconclusive
# 49892          Normal
# 49893          Normal
# 49894        Abnormal
# 49895          Normal
# 49896          Normal
# 49897          Normal
# 49898    Inconclusive
# 49899        Abnormal
# 49900          Normal
# 49901        Abnormal
# 49902        Abnormal
# 49903        Abnormal
# 49904          Normal
# 49905          Normal
# 49906          Normal
# 49907          Normal
# 49908    Inconclusive
# 49909        Abnormal
# 49910          Normal
# 49911        Abnormal
# 49912          Normal
# 49913    Inconclusive
# 49914        Abnormal
# 49915          Normal
# 49916          Normal
# 49917          Normal
# 49918        Abnormal
# 49919          Normal
# 49920    Inconclusive
# 49921    Inconclusive
# 49922    Inconclusive
# 49923    Inconclusive
# 49924          Normal
# 49925    Inconclusive
# 49926    Inconclusive
# 49927        Abnormal
# 49928          Normal
# 49929    Inconclusive
# 49930        Abnormal
# 49931    Inconclusive
# 49932        Abnormal
# 49933    Inconclusive
# 49934        Abnormal
# 49935          Normal
# 49936          Normal
# 49937        Abnormal
# 49938          Normal
# 49939          Normal
# 49940          Normal
# 49941          Normal
# 49942          Normal
# 49943    Inconclusive
# 49944    Inconclusive
# 49945          Normal
# 49946    Inconclusive
# 49947          Normal
# 49948        Abnormal
# 49949          Normal
# 49950          Normal
# 49951        Abnormal
# 49952        Abnormal
# 49953          Normal
# 49954        Abnormal
# 49955          Normal
# 49956        Abnormal
# 49957    Inconclusive
# 49958        Abnormal
# 49959        Abnormal
# 49960          Normal
# 49961        Abnormal
# 49962    Inconclusive
# 49963    Inconclusive
# 49964          Normal
# 49965        Abnormal
# 49966          Normal
# 49967    Inconclusive
# 49968    Inconclusive
# 49969          Normal
# 49970    Inconclusive
# 49971        Abnormal
# 49972        Abnormal
# 49973    Inconclusive
# 49974        Abnormal
# 49975          Normal
# 49976          Normal
# 49977        Abnormal
# 49978    Inconclusive
# 49979        Abnormal
# 49980    Inconclusive
# 49981        Abnormal
# 49982        Abnormal
# 49983    Inconclusive
# 49984    Inconclusive
# 49985          Normal
# 49986        Abnormal
# 49987    Inconclusive
# 49988    Inconclusive
# 49989          Normal
# 49990    Inconclusive
# 49991        Abnormal
# 49992          Normal
# 49993        Abnormal
# 49994    Inconclusive
# 49995    Inconclusive
# 49996        Abnormal
# 49997        Abnormal
# 49998        Abnormal
# 49999    Inconclusive
# Name: Test Results, dtype: object

# %%
# Test results for each medical condition
condition_vs_test = df.groupby('Medical Condition')['Test Results'].value_counts().unstack()
print("Test Results by Medical Condition:")
print(condition_vs_test)

# Visualise medication prescribed to the medical condition
plot=sns.countplot(data=df, x='Medical Condition', hue='Medication', palette='Set1')
sns.move_legend(plot,"upper center", bbox_to_anchor=(0.5, 1.17), frameon=False, ncol=5)
# Out:
# Test Results by Medical Condition:
# Test Results       Abnormal  Inconclusive  Normal
# Medical Condition
# Arthritis              2908          2789    2742
# Asthma                 2697          2721    2854
# Cancer                 2797          2751    2746
# Diabetes               2831          2766    2787
# Hypertension           2721          2789    2809
# Obesity                2818          2728    2746

# %%
# Patient count by admission type and medical condition 
admission_grouped = df.groupby(['Admission Type', 'Medical Condition']).size().reset_index(name='Count')

ad_plot=sns.barplot(data= admission_grouped, x='Admission Type',y='Count', hue='Medical Condition'  )
sns.move_legend(ad_plot,"upper center", bbox_to_anchor=(0.5, 1.2), frameon=False, ncol=3)
# admission_grouped

# %% [markdown]
# ## Key Observations from EDA:
# - The data does not contain missing values that need to be handled. <br>
# - The data shows little variation in hospital admission numbers per month with the average being ~4625 <br>
# - There is a large age range for each medical condition with the median, lower and upper quartile ranges for being quite similar for each condition. <br>
# - All medications are used to treat each medical condition.

# %%
# test results vs. disease

# %% [markdown]
# # Research Question:
# Can we identify distinct patient groups based on their billing amounts i.e. are higher costs associated with certain diseases, and length of stays, and do certain medical conditions lead to higher treatment costs than others? <br>
# <br>
# This could help hospital administrators optimise pricing strategies and resource allocation and nform policy makers about which are the most costly disease to treat.

# %% [markdown]
# ## Perform K-Means Clustering and determine k

# %%
data
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# 1            2019-08-20   Samantha Davies                       Kim Inc
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# 3            2020-11-18       Kevin Wells    Hernandez Rogers and Vang,
# 4            2022-09-19    Kathleen Hanna                   White-White
# ...                 ...               ...                           ...
# 55495        2020-08-16     Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23   Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13    Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25    Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02     Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0             Blue Cross    18856.281306          328         Urgent
# 1               Medicare    33643.327287          265      Emergency
# 2                  Aetna    27955.096079          205      Emergency
# 3               Medicare    37909.782410          450       Elective
# 4                  Aetna    14238.317814          458         Urgent
# ...                  ...             ...          ...            ...
# 55495         Blue Cross     2650.714952          417       Elective
# 55496              Cigna    31457.797307          316       Elective
# 55497   UnitedHealthcare    27620.764717          347         Urgent
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date   Medication  Test Results
# 0         2024-02-02  Paracetamol        Normal
# 1         2019-08-26    Ibuprofen  Inconclusive
# 2         2022-10-07      Aspirin        Normal
# 3         2020-12-18    Ibuprofen      Abnormal
# 4         2022-10-09   Penicillin      Abnormal
# ...              ...          ...           ...
# 55495     2020-09-15   Penicillin      Abnormal
# 55496     2020-02-01      Aspirin        Normal
# 55497     2020-08-10    Ibuprofen      Abnormal
# 55498     2019-05-31    Ibuprofen      Abnormal
# 55499     2024-04-29    Ibuprofen      Abnormal
#
# [55500 rows x 15 columns]

# %%
# # Prepare data for clustering
# df = data.copy()
# # Normalisation
# df

# %%
# for f in data.columns[1:-1]:
#   plt.scatter(data['Billing Amount'], data[f])
#   plt.xlabel('Billing Amount')
#   plt.ylabel(f)
#   plt.show()

plt.scatter(data['Billing Amount'], days_of_stay, alpha=0.5)
# plt.bar(days_of_stay,data['Billing Amount'] )
# plt.xlabel('days_of_stay')
# plt.ylabel('Billing Amount')


plt.show()

# %%
(data['Billing Amount']<0)
unique_negatives = data.loc[data['Billing Amount'] < 0, 'Billing Amount'].unique()
print(unique_negatives)
# Out:
# [ -502.5078127  -1018.24537123  -306.36492514  -109.097122
#   -576.72790682  -135.98600049  -370.98367385 -1310.27289471
#   -692.40882013  -353.86518565  -378.96078411  -367.20395907
#   -198.28380639   -43.09852159  -857.12593271  -155.08202015
#   -211.72384541  -656.15307181  -227.99506358  -147.07219897
#   -124.75643302   -75.81945069   -26.11252312  -135.71907348
#   -308.58426883  -214.60542058  -892.27014024  -556.11508419
#   -224.63241738   -32.34872934  -100.6036059   -211.28373744
#   -676.85250166  -130.86753441  -233.9307282   -124.64903599
#    -68.31962076  -577.72910671   -43.29174791   -53.83208587
#   -532.76111854  -599.26535851  -887.02421899 -1316.61858129
#    -75.620194    -317.63292075   -90.07890133   -23.86672915
#   -600.50075394  -952.83119395  -492.17838656  -855.80428373
#   -591.91741867   -38.96615157  -271.71640639  -557.01470008
#   -136.16468765   -37.26774848  -230.57928254  -407.80082254
#  -1277.64533715  -786.62471649  -967.59470585  -860.61798708
#  -1015.69785573  -416.91482438   -97.85311734  -964.79861919
#   -311.75562526   -85.47570764  -808.46505711 -1520.42055461
#  -1306.662189    -652.18136938  -199.66379451  -529.96300577
#   -872.23111288  -279.84240514  -226.38112001 -1428.84394137
#  -1049.01234112   -36.21727035 -1129.99717586  -614.94558551
#   -228.5468538    -82.76582344  -483.7088935  -2008.49213986
#   -164.29738731  -820.16335126  -289.80162055 -1660.00937272
#   -378.746815    -378.69641078  -444.03936705  -824.22587729]

# %%
type(length_of_stay[1])
# Out:
# pandas._libs.tslibs.timedeltas.Timedelta

# %%
type(data['Billing Amount'][1])
# Out:
# numpy.float64

# %%
days_of_stay =[]
for i in length_of_stay:
    
    days_of_stay.append(i.days)
# pd.concat([days_of_stay, data['Billing Amount']], join='inner')
# days_of_stay

# %%
data['Billing Amount']
# Out:
# 0        18856.281306
# 1        33643.327287
# 2        27955.096079
# 3        37909.782410
# 4        14238.317814
#              ...
# 55495     2650.714952
# 55496    31457.797307
# 55497    27620.764717
# 55498    32451.092358
# 55499     4010.134172
# Name: Billing Amount, Length: 55500, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = np.reshape(days_of_stay,[-1, 1])
# days_test = pd.DataFrame(scaler.fit(data))

# %% [markdown]
# ## Predicting length of stay

# %% [markdown]
# Can we predict the length of stay? - random forest, XGBoost, Linear reg <br>
# Eval metrics

# %% [markdown]
# Classification problem
